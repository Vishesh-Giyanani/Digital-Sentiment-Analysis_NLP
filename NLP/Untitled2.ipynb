# %%
pip install matplotlib seaborn
# Out:
# Running cells with 'c:\Users\ritikar\AppData\Local\Programs\Python\Python38\python.exe' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'c:/Users/ritikar/AppData/Local/Programs/Python/Python38/python.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df=pd.read_csv("Final2.csv")
df=df.dropna(subset=['Appliances_label'],how='all')

# %%
df
# Out:
#       No. Of Responses         StartDate           EndDate         ResponseId  \
# 0                    3  31-08-2022 03:08  31-08-2022 03:50  R_2PtDeOQ7jSZMkC8
# 1                    4  31-08-2022 21:08  31-08-2022 21:12  R_pmac3PtlCLpoOIx
# 2                    5  31-08-2022 21:15  31-08-2022 21:32  R_1QtsGGovmx38mZR
# 3                    6  31-08-2022 21:40  31-08-2022 21:45  R_1l47TTWYyoJNW1R
# 4                    7     1/9/2022 4:07     1/9/2022 4:47  R_1mJhQPJjVUyfvHU
# ...                ...               ...               ...                ...
# 1715              1718  14-10-2022 02:26  14-10-2022 02:38  R_1EhWnAQEZEgMhHs
# 1716              1719  14-10-2022 02:03  14-10-2022 02:45  R_78VOfb1D4auOlrj
# 1717              1720  14-10-2022 02:39  14-10-2022 02:53  R_3EFh38TdCclsFdP
# 1718              1721  14-10-2022 02:41  14-10-2022 02:54  R_snxvfJ86HHeDRaV
# 1719              1722  14-10-2022 02:48  14-10-2022 02:56  R_10rezqhqPLJhnKI
#
#       Appliances-Score Appliances-Text  Locks-Score  \
# 0                  NaN            fthg          0.0
# 1                  NaN             NaN          NaN
# 2                  NaN             NaN          NaN
# 3                  NaN              as          9.0
# 4                  7.0       dfgdfgdfg          NaN
# ...                ...             ...          ...
# 1715               NaN             NaN         10.0
# 1716               NaN             NaN         10.0
# 1717               NaN             NaN         10.0
# 1718               NaN             NaN         10.0
# 1719               NaN             NaN         10.0
#
#                                              Locks-Text  Interio-Score  \
# 0                                                   NaN            0.0
# 1                                                   NaN            NaN
# 2                                                   NaN            NaN
# 3                                                   NaN            NaN
# 4                                                   NaN            8.0
# ...                                                 ...            ...
# 1715  Because godrej is one of the oldest brand in I...            NaN
# 1716                                      best in locks            NaN
# 1717                                       Good Quality            NaN
# 1718                              godrej is very useful            NaN
# 1719                                        Good brand             NaN
#
#      Interio-Text  ...  Interio-Text_Negative Interio-Text_Neutral  \
# 0             NaN  ...               0.239502             0.528189
# 1             NaN  ...               0.239502             0.528189
# 2             NaN  ...               0.239502             0.528189
# 3             NaN  ...               0.239502             0.528189
# 4             NaN  ...               0.239502             0.528189
# ...           ...  ...                    ...                  ...
# 1715          NaN  ...               0.239502             0.528189
# 1716          NaN  ...               0.239502             0.528189
# 1717          NaN  ...               0.239502             0.528189
# 1718          NaN  ...               0.239502             0.528189
# 1719          NaN  ...               0.239502             0.528189
#
#      Interio-Text_Positive Security-Text_Negative Security-Text_Neutral  \
# 0                      0.0               0.239502              0.528189
# 1                      0.0               0.239502              0.528189
# 2                      0.0               0.239502              0.528189
# 3                      0.0               0.239502              0.528189
# 4                      0.0               0.239502              0.528189
# ...                    ...                    ...                   ...
# 1715                   0.0               0.239502              0.528189
# 1716                   0.0               0.239502              0.528189
# 1717                   0.0               0.239502              0.528189
# 1718                   0.0               0.239502              0.528189
# 1719                   0.0               0.239502              0.528189
#
#      Security-Text_Positive Appliances_label        Locks_label Interio_label  \
# 0                       0.0                           Detractor     Detractor
# 1                       0.0
# 2                       0.0
# 3                       0.0                   Revised Detractor
# 4                       0.0        Detractor                        Detractor
# ...                     ...              ...                ...           ...
# 1715                    0.0                            Promoter
# 1716                    0.0                   Revised Detractor
# 1717                    0.0                            Promoter
# 1718                    0.0                            Promoter
# 1719                    0.0                            Promoter
#
#      Security_label
# 0
# 1
# 2
# 3
# 4
# ...             ...
# 1715
# 1716
# 1717
# 1718
# 1719
#
# [1720 rows x 38 columns]

# %%
# plot the bar chart
sns.barplot(x='Appliances_label', y='No. Of Responses', palette = 'pastel', ci = None, data=df)

plt.xticks(rotation=45)
plt.xlabel('Labelling of customers', fontsize=14)
plt.ylabel('No. of responses', fontsize=14)
plt.title("Appliances")
plt.show()
# Out:
# <ipython-input-8-09f1aa202226>:2: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Appliances_label', y='No. Of Responses', palette = 'pastel', ci = None, data=df)

# %%
df.isnull().sum()
# Out:
# No. Of Responses               0
# StartDate                      0
# EndDate                        0
# ResponseId                     0
# Appliances-Score            1091
# Appliances-Text             1087
# Locks-Score                  997
# Locks-Text                  1001
# Interio-Score               1059
# Interio-Text                1062
# Security-Score               975
# Security-Text                977
# City                           0
# Age                            0
# Gender                         0
# Education                      0
# NCCS categorization            0
# Occupation                     0
# Household Income             147
# Marrital Status                0
# Household Ages               575
# Household Volunme           1706
# Appliances-Text_Negative      30
# Appliances-Text_Neutral       30
# Appliances-Text_Positive      30
# Locks-Text_Negative           28
# Locks-Text_Neutral            28
# Locks-Text_Positive           28
# Interio-Text_Negative         33
# Interio-Text_Neutral          33
# Interio-Text_Positive         33
# Security-Text_Negative        19
# Security-Text_Neutral         19
# Security-Text_Positive        19
# Appliances_label               0
# Locks_label                    0
# Interio_label                  0
# Security_label                 0
# dtype: int64

# %%
df['Appliances_label'].replace('', pd.NA, inplace=True)
df
# Out:
#       No. Of Responses         StartDate           EndDate         ResponseId  \
# 0                    3  31-08-2022 03:08  31-08-2022 03:50  R_2PtDeOQ7jSZMkC8
# 1                    4  31-08-2022 21:08  31-08-2022 21:12  R_pmac3PtlCLpoOIx
# 2                    5  31-08-2022 21:15  31-08-2022 21:32  R_1QtsGGovmx38mZR
# 3                    6  31-08-2022 21:40  31-08-2022 21:45  R_1l47TTWYyoJNW1R
# 4                    7     1/9/2022 4:07     1/9/2022 4:47  R_1mJhQPJjVUyfvHU
# ...                ...               ...               ...                ...
# 1715              1718  14-10-2022 02:26  14-10-2022 02:38  R_1EhWnAQEZEgMhHs
# 1716              1719  14-10-2022 02:03  14-10-2022 02:45  R_78VOfb1D4auOlrj
# 1717              1720  14-10-2022 02:39  14-10-2022 02:53  R_3EFh38TdCclsFdP
# 1718              1721  14-10-2022 02:41  14-10-2022 02:54  R_snxvfJ86HHeDRaV
# 1719              1722  14-10-2022 02:48  14-10-2022 02:56  R_10rezqhqPLJhnKI
#
#       Appliances-Score Appliances-Text  Locks-Score  \
# 0                  NaN            fthg          0.0
# 1                  NaN             NaN          NaN
# 2                  NaN             NaN          NaN
# 3                  NaN              as          9.0
# 4                  7.0       dfgdfgdfg          NaN
# ...                ...             ...          ...
# 1715               NaN             NaN         10.0
# 1716               NaN             NaN         10.0
# 1717               NaN             NaN         10.0
# 1718               NaN             NaN         10.0
# 1719               NaN             NaN         10.0
#
#                                              Locks-Text  Interio-Score  \
# 0                                                   NaN            0.0
# 1                                                   NaN            NaN
# 2                                                   NaN            NaN
# 3                                                   NaN            NaN
# 4                                                   NaN            8.0
# ...                                                 ...            ...
# 1715  Because godrej is one of the oldest brand in I...            NaN
# 1716                                      best in locks            NaN
# 1717                                       Good Quality            NaN
# 1718                              godrej is very useful            NaN
# 1719                                        Good brand             NaN
#
#      Interio-Text  ...  Interio-Text_Negative Interio-Text_Neutral  \
# 0             NaN  ...               0.239502             0.528189
# 1             NaN  ...               0.239502             0.528189
# 2             NaN  ...               0.239502             0.528189
# 3             NaN  ...               0.239502             0.528189
# 4             NaN  ...               0.239502             0.528189
# ...           ...  ...                    ...                  ...
# 1715          NaN  ...               0.239502             0.528189
# 1716          NaN  ...               0.239502             0.528189
# 1717          NaN  ...               0.239502             0.528189
# 1718          NaN  ...               0.239502             0.528189
# 1719          NaN  ...               0.239502             0.528189
#
#      Interio-Text_Positive Security-Text_Negative Security-Text_Neutral  \
# 0                      0.0               0.239502              0.528189
# 1                      0.0               0.239502              0.528189
# 2                      0.0               0.239502              0.528189
# 3                      0.0               0.239502              0.528189
# 4                      0.0               0.239502              0.528189
# ...                    ...                    ...                   ...
# 1715                   0.0               0.239502              0.528189
# 1716                   0.0               0.239502              0.528189
# 1717                   0.0               0.239502              0.528189
# 1718                   0.0               0.239502              0.528189
# 1719                   0.0               0.239502              0.528189
#
#      Security-Text_Positive Appliances_label        Locks_label Interio_label  \
# 0                       0.0                           Detractor     Detractor
# 1                       0.0
# 2                       0.0
# 3                       0.0                   Revised Detractor
# 4                       0.0        Detractor                        Detractor
# ...                     ...              ...                ...           ...
# 1715                    0.0                            Promoter
# 1716                    0.0                   Revised Detractor
# 1717                    0.0                            Promoter
# 1718                    0.0                            Promoter
# 1719                    0.0                            Promoter
#
#      Security_label
# 0
# 1
# 2
# 3
# 4
# ...             ...
# 1715
# 1716
# 1717
# 1718
# 1719
#
# [1720 rows x 38 columns]

# %%
sns.barplot(x='Locks_label', y="No. Of Responses", palette='pastel',ci=None, data=df)

plt.xticks(rotation=45)
plt.xlabel('Labelling of customers', fontsize=14)
plt.ylabel('No. of responses', fontsize=14)
plt.title("Locks")
plt.show()
# Out:
# <ipython-input-126-4ce75b7fcf69>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Locks_label', y="No. Of Responses", palette='pastel',ci=None, data=df)

# %%
sns.barplot(x='Interio_label', y="No. Of Responses", palette='pastel',ci=None, data=df)

plt.xticks(rotation=45)
plt.xlabel('Labelling of customers', fontsize=14)
plt.ylabel('No. of responses', fontsize=14)
plt.title("Interio")
plt.show()
# Out:
# <ipython-input-125-0863c794e0af>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Interio_label', y="No. Of Responses", palette='pastel',ci=None, data=df)

# %%
sns.barplot(x='Security_label', y="No. Of Responses", palette='pastel',ci=None, data=df)

plt.xticks(rotation=45)
plt.xlabel('Labelling of customers', fontsize=14)
plt.ylabel('No. of responses', fontsize=14)
plt.title("Security")
plt.show()
# Out:
# <ipython-input-124-6f6699446460>:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Security_label', y="No. Of Responses", palette='pastel',ci=None, data=df)
