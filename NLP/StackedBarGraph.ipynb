# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Loading the input file
df = pd.read_csv("Final2.csv")

# Calculate the counts for each label and category
counts_appliances = df['Appliances_label'].value_counts()
counts_locks = df['Locks_label'].value_counts()
counts_interio = df['Interio_label'].value_counts()
counts_security = df['Security_label'].value_counts()

# Create a DataFrame with the counts 
df_counts = pd.DataFrame({'Appliances': counts_appliances, 'Locks': counts_locks, 'Interio': counts_interio, 'Security': counts_security})

# Transpose the DataFrame
df_counts = df_counts.transpose()



# Create a stacked bar plot
ax = df_counts.plot(kind='bar', stacked=True, color=["#4169E1", "#FFDAB9", "#9467bd"])



# Set the title and labels
plt.xticks(rotation=0)
#plt.title('Comparison of Detractors, Promoters, Revised Detractors and Revised Promoters of Appliances, Locks, Interio and Security')
plt.title('Comparison of Positives, Negatives and Neutrals of Appliances, Locks, Interio and Security')
plt.xlabel('Business Units', fontsize=14)
plt.ylabel('Number of Customer', fontsize=14)

ax.legend(loc='upper center', bbox_to_anchor=(1.2, 0.5), ncol=1)

# Get the current axis object
ax = plt.gca()

# Set the x-axis tick labels position to bottom
ax.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=True)

# Set the y-axis tick labels pos\\\\\ ition to left
ax.tick_params(axis='y', which='both', left=True, right=False, labelleft=True)

# Set the x and y-axis label positions
ax.xaxis.set_label_coords(0.5, -0.15)
ax.yaxis.set_label_coor (-0.1, 0.5)

# Show the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 47
#      45 # Set the x and y-axis label positions
#      46 ax.xaxis.set_label_coords(0.5, -0.15)
# ---> 47 ax.yaxis.set_label_coor (-0.1, 0.5)
#      49 # Show the plot
#      50 plt.show()
#
# AttributeError: 'YAxis' object has no attribute 'set_label_coor'
