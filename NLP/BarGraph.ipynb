# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df=pd.read_csv("Iteration_2.csv")

# %%
# plot the bar chart


sns.barplot(x='Appliances_label', y = df['Unnamed: 0'], palette = ["darkblue","orange","grey","maroon"], ci = None, data=df)

plt.xticks(rotation=0)
plt.xlabel('Labelling of customers', fontsize=14)
plt.ylabel('No. of responses', fontsize=14)
plt.title("Appliances")

ax = plt.gca()

# Set the x-axis tick labels position to bottom
ax.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=True)

# Set the y-axis tick labels position to left
ax.tick_params(axis='y', which='both', left=True, right=False, labelleft=True)

# Set the x and y-axis label positions
ax.xaxis.set_label_coords(0.5, -0.15)
ax.yaxis.set_label_coords(-0.1, 0.5)

plt.show()
# Out:
# C:\Users\ritikar\AppData\Local\Temp\ipykernel_8312\2882436686.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Appliances_label', y = df['Unnamed: 0'], palette = ["darkblue","orange","grey","maroon"], ci = None, data=df)

# %%
sns.barplot(x='Locks_label', y = df['Unnamed: 0'], palette=["darkblue","orange","grey","maroon"],ci=None, data=df)

plt.xticks(rotation=0)
plt.xlabel('Labelling of customers', fontsize=14)
plt.ylabel('No. of responses', fontsize=14)
plt.title("Locks")

ax = plt.gca()

# Set the x-axis tick labels position to bottom
ax.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=True)

# Set the y-axis tick labels position to left
ax.tick_params(axis='y', which='both', left=True, right=False, labelleft=True)

# Set the x and y-axis label positions
ax.xaxis.set_label_coords(0.5, -0.15)
ax.yaxis.set_label_coords(-0.1, 0.5)

plt.show()
# Out:
# C:\Users\ritikar\AppData\Local\Temp\ipykernel_8312\3107374810.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Locks_label', y = df['Unnamed: 0'], palette=["darkblue","orange","grey","maroon"],ci=None, data=df)

# %%
sns.barplot(x='Interio_label', y=df['Unnamed: 0'], palette=["darkblue","orange","grey","maroon"],ci=None, data=df)

plt.xticks(rotation=0)
plt.xlabel('Labelling of customers', fontsize=14)
plt.ylabel('No. of responses', fontsize=14)
plt.title("Interio")

ax = plt.gca()

# Set the x-axis tick labels position to bottom
ax.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=True)

# Set the y-axis tick labels position to left
ax.tick_params(axis='y', which='both', left=True, right=False, labelleft=True)

# Set the x and y-axis label positions
ax.xaxis.set_label_coords(0.5, -0.15)
ax.yaxis.set_label_coords(-0.1, 0.5)

plt.show()
# Out:
# C:\Users\ritikar\AppData\Local\Temp\ipykernel_8312\2184877083.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Interio_label', y=df['Unnamed: 0'], palette=["darkblue","orange","grey","maroon"],ci=None, data=df)

# %%
sns.barplot(x='Security_label', y=df['Unnamed: 0'], palette=["darkblue","orange","grey","maroon"],ci=None, data=df)

plt.xticks(rotation=0)
plt.xlabel('Labelling of customers', fontsize=14)
plt.ylabel('No. of responses', fontsize=14)
plt.title("Security")

ax = plt.gca()

# Set the x-axis tick labels position to bottom
ax.tick_params(axis='x', which='both', bottom=False, top=False, labelbottom=True)

# Set the y-axis tick labels position to left
ax.tick_params(axis='y', which='both', left=True, right=False, labelleft=True)

# Set the x and y-axis label positions
ax.xaxis.set_label_coords(0.5, -0.15)
ax.yaxis.set_label_coords(-0.1, 0.5)

plt.show()
# Out:
# C:\Users\ritikar\AppData\Local\Temp\ipykernel_8312\2643255922.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Security_label', y=df['Unnamed: 0'], palette=["darkblue","orange","grey","maroon"],ci=None, data=df)
